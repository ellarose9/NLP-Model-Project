# %% [markdown]
# <a href="https://colab.research.google.com/github/ellarose9/NLP-Model-Project/blob/main/Data_Analysis_and_Cleanup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import packages
import os
import random
import string
import nltk
from collections import defaultdict
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
import pickle
import pandas as pd
from nltk.corpus import stopwords
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Create  tuple with complaints, where the first part is the Main Problem, and the second part is the narrative
# It should look like this: [ (Main Problem, narrative), (Main Problem, narrative)]
# Note, I removed all the commas from the .csv file prior to running this, since we are splitting on ,
 
complaints = pd.read_csv('Test_Data.csv', delimiter=',')
 
docs = [tuple(row) for row in complaints.values]

# %%
#Printing the first few to make sure it worked
print(docs[0:5])
# Out:
# [('Credit Card or Credit Reporting Help', 'This bank has been against me and refuses to process any of my store credit cards applications they immediately decline me with no reason not fair they hate me my XXXX XXXX XXXX XXXX XXXX this is not nice'), ('Incorrect Information', 'XXXX XXXX XXXX XXXX XXXX. TX XXXX I just got my report and I think it is wrong! I was told I have the right to have an investigation done. The XXXX XXXX Account depicts an old account as a charge off. I paid the account opened in XXXX off completely. I opened a new account in XXXX and XXXX XXXX reported I opened it in XXXX and charged off the new account. The account on my credit report is false. The Credit bureaus laws report that the bureaus report 100 % accurate credit history. Every step must be taken to assure that the information reported is completely accurate. The following information therefore needs to be reinvestigated. Please make sure everything pertaining to my credit report is correct. \n\nPlease provide me with the following items : 1. Pay Off Disclosure 2. Interest Disclosure 3. Balance History 4. Payment History 5. Credit Insurance Validate Account XXXX XXXX XXXX Closed ( 5 ) TREATMENT OF INACCURATE OR UNVERIFIABLE INFORMATION. \n( A ) IN GENERAL.If. after any reinvestigation under paragraph ( XXXX ) of any information disputed by a consumer. an item of the information is found to be inaccurate or incomplete or can not be verified. the consumer reporting agency shall ( i ) promptly delete that item of information from the file of the consumer. or modify that item of information. as appropriate. based on the results of the reinvestigation; and ( ii ) promptly notify the furnisher of that information that the information has been modified or deleted from the file of the consumer.'), ('Credit Card or Credit Reporting Help', 'i am filing this complaint because XXXX. transunion and XXXX has ignored my request to provide me with the documents that their company has on file that was used to verify the accounts i disputed. being that they have gone past the 30 day mark and can not verify these account under section 611 ( 5 ) ( a ) of the fcra - they are required to promptly delete all information which can not be verified that i have disputed. please resolve this issue immediately.'), ('Loan or Lease Help', 'Volvo Car Financial Services ( VCFS ) offers a vehicle lease extension option on their website. for XXXX. XXXX. or 3 months. On XX/XX/XXXX. I selected XXXX and the automated response said I would hear back. \n\nWhen I did not hear back. I called VCFS today ( XX/XX/XXXX ). I was told they only extend leases when you have an order placed with a dealership. If that is the case. along with being a consumer-unfriendly policy. it is radically misleading to even offer the extension option on the website without this important qualifier. That is my first complaint. My attachments show the denial issued. \n\nMoreover. the VCFS representative told me on the phone I did receive a reply. I checked my email and recent voicemails. Had neither. But. it turns out. that yes. I did receive a denial via VCFS \' messaging platform. That messaging platform does not notify the consumer through any other means when you get a message. No email to say " you have a secure message \'\' or anything of the sort. Had a not followed up with VCFS. I never would have known. That would be my second complaint.\n\nI am also attaching the full message history via VCFS \' " secure messaging \'\' which shows that the denial was made without my providing a single fact and was a denial that appears consistent with Volvo \'s maintaining a policy of no extensions. I am also attaching a screenshot of the message I got when submitting an extension request ( for the purposes of this complaint. I just requested another extension via the website ). that suggests I\'ll be hearing back in 48hrs.'), ('Incorrect Information', 'XXXX XXXX XXXX furnished information on my credit file with extor ...

# %%
#We want to clean up the narrative so that we will only see meaningful words
#First step is to remove puncuation and convert to lower case
def clean_text(text):
  #remove punctuation
  text = text.translate(str.maketrans('','', string.punctuation))
  #convert to lower case
  text = text.lower()
  return text

# %%
stop_words = set(nltk.corpus.stopwords.words('english'))
stop_words.add('said')
stop_words.add('mr')
stop_words.add('xxxx')
stop_words.add("i")

# %%
def get_tokens(text):
  tokens = word_tokenize(text)
  tokens = tuple((t for t in tokens if not t in stop_words))
  return tokens

# %%
category_label = ["Incorrect Information", "Credit Card or Credit Reporting Help", "Loan or Lease Help","Mortgage Help","Administrative Help","Identity Theft or Fraud","Debit Card Help", "Billing or Debt Disputes","Service Disputes"]

# %%
# Analysis of what the most frequently used words are in the narratives
def print_frequency_dist(docs):
  tokens = defaultdict(list)

  # making a big list of all the words in each Main Problem

  for doc in docs:
    doc_problem = doc[0]
    doc_narrative = clean_text(doc[1])

    doc_tokens = get_tokens(doc_narrative)

    tokens[doc_problem].append(doc_tokens)

  for category_label, category_tokens in tokens.items():
    print(category_label)
    fd = FreqDist(category_tokens)
    print(fd.most_common(20))

# %%
#Creating a shorter version of the complaint set so that we can see results fast
docs_short = docs[0:2000]

# %%
#Calling print_frequency_dist to see how it looks
#This will take a while to run if you do it on the full file
#If you want to see the full result, replace docs_short with docs
print_frequency_dist(docs_short)
# Out:
# Credit Card or Credit Reporting Help
# [(('name', 'complaint', 'made', 'error', 'neither', 'made', 'third', 'partyi', 'declare', 'penalty', 'perjury', 'alleging', 'person', 'company', 'without', 'authorization', 'unauthorized', 'use', 'social', 'security', 'number', 'card', 'used', 'personal', 'identifying', 'information', 'apply', 'goods', 'services', 'money', 'successful', 'creating', 'accounts', 'knowledge', 'investigated', 'ftc', '15', 'us', 'code', '1681b', 'permissible', 'purposes', 'consumer', 'reports', 'never', 'gave', 'written', 'consent', 'report', 'anything', 'consumer', 'reports', 'consent', 'fraud'), 16), (('name', 'third', 'party', 'involved', 'filing', 'complaint', 'complaint', 'made', 'error'), 8), (('accordance', 'fair', 'credit', 'reporting', 'act', 'account', 'violated', 'rights', '15', 'usc', '1681', 'section', '602', 'astates', 'right', 'privacy', '15', 'usc', '1681', 'section', '604', 'section', '2', 'also', 'states', 'consumer', 'reporting', 'agency', 'furnish', 'account', 'without', 'written', 'instructions', '15', 'usc', '1666b', 'creditor', 'may', 'treat', 'payment', 'credit', 'account', 'open', 'en', 'consumer', 'credit', 'plan', 'late', 'purpose'), 5), (('items', 'reflected', 'credit', 'report', 'inaccurate', 'duty', 'inform', 'consumers', 'things', 'need', 'know', 'accurately', 'kindly', 'conduct', 'investigations', 'accounts', 'inquiries', 'update', 'accordingly', 'seek', 'litigation'), 4), (('xxxx2023', 'sent', 'letter', 'regarding', 'inaccurate', 'late', 'payments', 'inaccurate', 'negative', 'accounts', 'bankruptcies', 'unknown', 'things', 'credit', 'report', 'day', '60', 'days', 'later', 'received', 'response', 'yet', 'feel', 'like', 'im', 'taken', 'advantage', 'ignored', 'disputes', 'section', '611', 'plainly', 'stated', 'failure', 'investigate', 'items', 'within', '30', 'days', 'gives', 'reason', 'immediately', 'remove', 'negative', 'items', 'credit', 'report', 'well', 'correct', 'late', 'payments', 'paid', 'time', '60', 'days', 'corrected', 'promptly', 'demand', 'negative', 'accounts', 'deleted', 'correct', 'late', 'payments', 'paid', 'time', 'immediately', 'file', 'litigation', 'due', 'stress', 'caused', 'information', 'also', 'impacted', 'equifax', 'data', 'breach', 'may', 'got', 'hands', 'wrong', 'person'), 4), (('requested', 'signed', 'document', 'handwritten', 'signature', 'sent', 'mailing', 'address', 'verify', 'account', 'however', 'signed', 'document', 'never', 'sent'), 4), (('name', 'complaint', 'made', 'error', 'neither', 'made', 'third', 'partyi', 'declare', 'penalty', 'perjury', 'alleging', 'person', 'company', 'without', 'authorization', 'unauthorized', 'use', 'social', 'security', 'number', 'card', 'used', 'personal', 'identifying', 'information', 'apply', 'goods', 'services', 'money', 'successful', 'creating', 'accounts', 'knowledge', 'investigated', 'ftc'), 4), (('accordance', 'fair', 'credit', 'reporting', 'act', 'account', 'violated', 'rights', '15', 'usc', '1681', 'section', '602', 'states', 'right', 'privacy', '15', 'usc', '1681', 'section', '604', 'section', '2', 'also', 'states', 'consumer', 'reporting', 'agency', 'furnish', 'account', 'without', 'written', 'instructions'), 3), (('accordance', 'fair', 'credit', 'reporting', 'act', 'account', 'account', 'account', 'account', 'violated', 'rights', '15', 'usc', '1681', 'section', '602', 'states', 'right', 'privacy', '15', 'usc', '1681', 'section', '604', 'section', '2', 'also', 'states', 'consumer', 'reporting', 'agency', 'furnish', 'account', 'without', 'written', 'instructions'), 3), (('names', 'account', 'account', 'number', 'dear', 'customer', 'service', 'department', 'please', 'review', 'records', 'find', 'account', 'current', 'loyal', 'customer', 'since', 'please', 'find', 'aside', 'late', 'payment', 'xxxxxxxx', 'never', 'missed', 'payment', 'please', 'find', 'account', 'remains', 'positive', 'standing', 'upon', 'approaching', 'end', 'lease', 'approximately', 'two', 'months', 'payment', 'xxxxxxxx', '35', 'days', 'late', 'resolved', 'brought', 'account',  ...
# Incorrect Information
# [(('despite', 'sending', 'ftc', 'reports', 'police', 'reports', 'notarized', 'documents', 'filing', 'disputes', 'hiring', 'credit', 'repair', 'company', 'three', 'credit', 'bureaus', 'several', 'creditors', 'still', 'reporting', 'fraudulent', 'information', 'removed', 'items', 'please', 'see', 'attached', 'supporting', 'documents', 'explain', 'situation', 'accounts', 'dispute', 'complaints', 'filed', 'bureaus', 'creditors', 'going', 'years', 'extremely', 'damaging', 'credit', 'costing', 'money', 'fight', 'want', 'items', 'removed', 'immediately', 'ftc', 'police', 'reports', 'attached'), 6), (('hi', 'submitting', 'isnt', 'influence', 'third', 'party', 'low', 'unfair', 'credit', 'number', 'report', 'complained', 'problem', 'resolved', 'fico', 'credit', 'score', '719xxxx', 'score', 'around', '590', 'huge', 'difference', 'paints', 'fico', 'say', 'good', 'credit', 'heck', 'going', 'almost', 'debt', 'identity', 'stolen', 'causing', 'score', 'drop', 'n', 'made', 'clear', '60', 'days', 'straight', 'spoke', 'representative', 'agent', 'name', 'fraud', 'department', 'prefer', 'speak', 'us', 'rept', 'refused', 'mute', '4', 'hours', 'hurtful', 'perfect', 'repayment', 'record', 'low', 'credit', 'utilization', 'three', 'negative', 'credit', 'items', 'outstanding', 'debt', 'modest', 'ok', 'income', 'social', 'security', 'something', 'wrong', 'understand', 'abusing', 'consumers', 'fist', 'step', 'towards', 'attempting', 'resolution', 'kept', 'lying', 'telling', 'disputed', 'n', 'reporting', 'keep', 'reporting', 'inaccurate', 'information', 'without', 'authorization', 'refused', 'unable', 'verify', 'n', 'remove', 'inquiries', '60days', 'n', 'record', 'calls', 'n', 'admitted', 'police', 'report', 'n', 'ftc', 'affidavit', 'attempting', 'contact', '21', 'times', 'abusive', 'company', 'supposed', 'protecting', 'consumers', 'need', 'reigned', 'causing', 'severe', 'stopping', 'getting', 'job', 'offer', 'n', 'im', 'n', 'cant', 'provide', 'year', 'old', 'daughter', 'please', 'help', 'please', 'im', 'nowwith', 'help'), 5), (('hi', 'submitting', 'isnt', 'influence', 'third', 'party', 'transunion', 'low', 'unfair', 'credit', 'number', 'report', 'complained', 'problem', 'resolved', 'fico', 'credit', 'score', '719transunion', 'score', 'around', '590', 'huge', 'difference', 'transunion', 'paints', 'fico', 'say', 'good', 'credit', 'heck', 'going', 'almost', 'debt', 'identity', 'stolen', 'causing', 'score', 'drop', 'n', 'made', 'clear', '60', 'days', 'straight', 'transunion', 'spoke', 'representative', 'agent', 'name', 'fraud', 'department', 'prefer', 'speak', 'us', 'rept', 'refused', 'mute', '4', 'hours', 'hurtful', 'perfect', 'repayment', 'record', 'low', 'credit', 'utilization', 'three', 'negative', 'credit', 'items', 'outstanding', 'debt', 'modest', 'ok', 'income', 'social', 'security', 'something', 'wrong', 'transunion', 'understand', 'abusing', 'consumers', 'fist', 'step', 'towards', 'attempting', 'resolution', 'kept', 'lying', 'telling', 'disputed', 'n', 'reporting', 'keep', 'reporting', 'inaccurate', 'information', 'without', 'authorization', 'refused', 'unable', 'verify', 'n', 'remove', 'inquiries', '60days', 'n', 'record', 'calls', 'n', 'admitted', 'police', 'report', 'n', 'ftc', 'affidavit', 'attempting', 'contact', 'transunion', '21', 'times', 'transunion', 'abusive', 'company', 'supposed', 'protecting', 'consumers', 'need', 'reigned', 'causing', 'severe', 'stopping', 'getting', 'job', 'offer', 'n', 'im', 'n', 'cant', 'provide', 'year', 'old', 'daughter', 'please', 'help', 'please', 'im', 'nowwith', 'help'), 3), (('follow', 'last', 'complaint', 'sending', 'sent', 'clarification', 'know', 'fraud', 'began', 'reported', 'soon', 'saw', 'reports', 'several', 'student', 'loans', 'good', 'standing', 'knowledge', 'one', 'random', 'letter', 'sent', 'doesnt', 'even', 'account', 'number', 'loans', 'federal', 'private', 'see', 'nothing', 'authorizing', 'loan', 'demand', 'proof', 'signing', 'loan', 'sent', 'failed', 'verify', 'debt'), 2), (('auto', 'lease', 'di ...
# Loan or Lease Help
# [(('volvo', 'car', 'financial', 'services', 'vcfs', 'offers', 'vehicle', 'lease', 'extension', 'option', 'website', '3', 'months', 'xxxxxxxx', 'selected', 'automated', 'response', 'would', 'hear', 'back', 'hear', 'back', 'called', 'vcfs', 'today', 'xxxxxxxx', 'told', 'extend', 'leases', 'order', 'placed', 'dealership', 'case', 'along', 'consumerunfriendly', 'policy', 'radically', 'misleading', 'even', 'offer', 'extension', 'option', 'website', 'without', 'important', 'qualifier', 'first', 'complaint', 'attachments', 'show', 'denial', 'issued', 'moreover', 'vcfs', 'representative', 'told', 'phone', 'receive', 'reply', 'checked', 'email', 'recent', 'voicemails', 'neither', 'turns', 'yes', 'receive', 'denial', 'via', 'vcfs', 'messaging', 'platform', 'messaging', 'platform', 'notify', 'consumer', 'means', 'get', 'message', 'email', 'say', 'secure', 'message', 'anything', 'sort', 'followed', 'vcfs', 'never', 'would', 'known', 'would', 'second', 'complaint', 'also', 'attaching', 'full', 'message', 'history', 'via', 'vcfs', 'secure', 'messaging', 'shows', 'denial', 'made', 'without', 'providing', 'single', 'fact', 'denial', 'appears', 'consistent', 'volvo', 'maintaining', 'policy', 'extensions', 'also', 'attaching', 'screenshot', 'message', 'got', 'submitting', 'extension', 'request', 'purposes', 'complaint', 'requested', 'another', 'extension', 'via', 'website', 'suggests', 'ill', 'hearing', 'back', '48hrs'), 1), (('citimortgage', 'increased', 'mortgage', 'payment', '21000', 'per', 'month', 'citimortgage', 'stated', 'started', 'receive', 'notification', 'citimortgage', 'mortgage', 'increased', '21000', 'per', 'month', 'payments', 'made', 'bank', 'payments', 'sent', 'received', 'citimortgage', 'ontime', 'citimortgage', 'legally', 'allowed', 'citimortgage', 'apply', 'payments', 'declared', 'default', 'mortgage', 'normally', 'citimortgage', 'notifies', 'two', 'full', 'months', 'advance', 'legal', 'sized', 'colorful', 'form', 'explaining', 'increase', 'decrease', 'first', 'learned', 'increase', 'received', 'credit', 'report', 'noticed', 'lien', 'placed', 'property', '22000', 'called', 'citimortgage', 'see', 'placed', 'lien', 'citimortgage', 'informed', 'payment', 'late', 'shocked', 'payments', 'scheduled', 'paid', 'directly', 'citimortgage', 'checking', 'account', 'money', 'already', 'taken', 'checking', 'account', 'informed', 'citimortgage', 'outrageous', 'increase', 'property', 'taxes', 'house', 'insurance', 'increased', 'called', 'office', 'informed', 'taxes', 'year', 'taxes', 'year', 'reduced', 'decrease', '500', 'called', 'informed', 'house', 'insurance', 'increase', 'difference', 'per', 'yr', 'month', '21000', 'per', 'month', 'citimortgage', 'sent', 'refund', '50000', 'three', 'years', 'ago', 'thought', 'law', 'banks', 'overcharging', 'customers', 'sending', 'large', 'refund', 'interest', 'free', 'loan', 'citimortgage', 'never', 'given', 'anything', 'free', 'date', 'citimortgage', 'sent', 'formal', 'written', 'explanation', 'monthly', 'increase', 'scam', 'please', 'help', 'resolve', 'citimortgage', 'mailing', 'address', 'ny', 'notified', 'end', 'beginning', 'never', 'lost', 'citimortgage', 'called', 'citimortgage', 'three', 'times', 'concerning', 'home', 'located', 'ga', 'loan', 'number', 'yearly', 'female', 'veteran', 'thank', 'helping', 'mesincerely'), 1), (('currently', 'account', 'deferment', 'due', 'attendance', 'program', 'university', 'deferment', 'make', 'periodic', 'payments', 'towards', 'loan', 'autopay', 'turned', 'able', 'reestablish', 'autopay', 'service', 'surprise', 'using', 'campus', 'loan', 'website', 'found', 'charging', 'cent', 'fee', 'order', 'make', 'payments', 'processing', 'fee', 'use', 'creditdebit', 'card', 'past', 'able', 'make', 'additional', 'principal', 'payments', 'payments', 'deferment', 'using', 'checking', 'account', 'free', 'via', 'website', 'understand', 'recommended', 'use', 'autopay', 'service', 'past', 'however', 'since', 'deferment', 'convenience', 'incurs', 'charge', 'instructed', 'deliver', ...
# Mortgage Help
# [(('entered', 'forbearance', 'plan', 'citizen', 'due', 'covid', 'forbearance', 'plan', 'ended', 'xxxxxxxx', 'told', 'order', 'resume', 'making', 'payments', 'fill', 'loan', 'modification', 'form', 'payments', 'moved', 'back', 'loan', 'submitted', 'application', 'xxxxxxxx', 'verbally', 'told', 'approved', 'notary', 'contacting', 'sign', 'documents', 'needed', 'finalize', 'modification', 'hear', 'anyone', 'xxxxxxxx', 'called', 'regarding', 'modification', 'kept', 'getting', 'running', 'around', 'requested', 'speak', 'management', 'told', 'would', 'get', 'call', 'back', 'one', 'ever', 'called', 'back', 'kept', 'calling', 'day', 'someone', 'finally', 'advised', 'denied', 'due', 'lien', 'advised', 'liens', 'must', 'mistake', 'escalated', 'matter', 'chairman', 'office', 'reached', 'advise', 'specifics', 'advised', 'mistaken', 'identity', 'person', 'submitted', 'numerous', 'documents', 'proving', 'liens', 'home', 'provided', 'local', 'county', 'clerk', 'office', 'back', 'late', 'xxxxxxxx', 'xxxxxxxx', 'xxxxxxxx', 'still', 'yet', 'hear', 'anyone', 'regards', 'resolution', 'xxxxxxxx', 'received', 'letter', 'loan', 'default', 'begin', 'foreclosure', 'process', 'payment', 'full', 'received', 'xxxxxxxx', 'amount', '2400000', 'told', 'chairman', 'office', 'xxxxxxxx', 'investigated', 'everything', 'hold', 'investigation', 'complete', 'moving', 'forward', 'without', 'resolving', 'mixed', 'identity', 'issues', 'come', 'point', 'anxiety', 'levels', 'stress', 'levels', 'increased', 'tremendously', 'get', 'medication', 'increased', 'constant', 'monitoring', 'due', 'weeks', 'pregnant', 'citizens', 'bank', 'refusing', 'provide', 'information', 'call', 'responding', 'calls', 'emails'), 1), (('apologies', 'hardtoread', 'details', 'writing', 'see', 'portal', 'allow', 'proper', 'formatting', 'complaint', 'regarding', 'cooper', 'aka', 'nationstar', 'mortgage', 'llc', 'nyc', 'dept', 'consumer', 'affairs', 'texas', 'regulated', 'lender', 'license', 'failure', 'honor', 'alreadyapproved', 'loan', 'loan', 'ultimately', 'simply', 'wish', 'continue', 'making', 'payments', 'subject', 'propertyloan', 'originates', 'ny', 'ny', 'subject', 'lender', 'appears', 'based', 'texas', 'directed', 'attorney', 'documented', 'timeline', 'development', 'issue', 'cooper', 'acquired', 'loan', 'approximately', 'xxxx2022', 'mortgage', 'postpandemic', 'modification', 'already', 'established', 'already', 'place', 'well', 'past', 'approval', 'stage', 'acquired', 'cooper', 'missed', 'payments', 'fine', 'upon', 'notified', 'acquisition', 'called', 'cooper', 'spoke', 'regarding', 'send', 'payments', 'new', 'mortgage', 'co', 'told', 'wait', 'make', 'payments', 'send', 'send', 'paper', 'work', 'assumed', 'acquisition', 'formality', 'mailed', 'modification', 'documents', 'think', 'issue', 'figured', 'mere', 'formality', 'acquisition', 'upon', 'opening', 'mail', 'reviewing', 'documents', 'promptly', 'called', 'cooper', 'spoke', 'told', 'going', 'mail', 'back', 'modification', 'documents', 'payment', 'payment', '1300', 'previous', 'company', 'thought', 'issue', 'accepted', 'stated', 'mistake', 'payment', 'exactly', 'alreadyinplace', 'mortgage', 'send', 'payment', 'cooper', 'resend', 'revised', 'documents', 'signed', 'mailed', 'back', 'simply', 'wait', 'called', 'cooper', 'spoke', 'az', 'told', 'im', 'still', 'waiting', 'docs', 'wanted', 'send', 'payment', 'wait', 'still', 'waiting', 'review', 'wait', 'docs', 'mail', '41', 'min', 'ph', 'call', 'called', 'cooper', 'spoke', 'tx', 'loan', 'specialist', 'im', 'express', 'growing', 'concern', 'yet', 'receive', 'documents', 'would', 'allow', 'make', 'payments', 'mentioned', 'wanted', 'send', 'payments', 'could', 'see', 'crm', 'placed', 'calls', 'would', 'mark', 'escalated', 'higher', 'manager', 'handle', 'since', 'still', 'pending', 'explanation', 'call', 'cooper', 'spoke', 'tx', 'says', 'escalated', 'avp', 'mentioned', 'hes', 'never', 'seen', 'scenario', 'like', 'understand', 'yet', 'rectified', 'etc', 'etc', 'called', 'cooper', 'spoke', 'tx', ' ...
# Administrative Help
# [(('applied', 'checking', 'account', '2016', 'account', 'came', 'promotional', 'bonus', 'points', 'certain', 'terms', 'met', 'terms', 'indicated', '100000', 'would', 'spent', 'within', '60', 'days', 'account', 'opening', 'written', 'confirmation', 'citi', 'account', 'eligible', 'promo', 'completed', 'task', 'wrote', 'citi', 'confirming', 'eligibility', 'promo', 'met', 'terms', 'citi', 'wrote', 'back', 'fact', 'qualified', 'promotional', 'requirements', 'met', 'told', 'bonus', 'miles', 'would', 'accredited', 'account', 'xxxxxxxx16', 'rolled', 'around', 'points', 'awarded', 'reached', 'citi', 'time', 'telling', 'need', 'check', 'eligibility', 'despite', 'already', 'confirming', 'back', 'forth', 'conversation', 'real', 'answers', 'getting', 'charged', 'monthly', 'services', 'fees', 'original', 'told', 'response', 'would', 'received', 'xxxx4', 'business', 'days', 'despite', 'multiple', 'attempts', 'still', 'received', 'response', 'citi'), 1), (('bank', 'america', 'closed', 'account', 'xxxxxxxx2015', 'never', 'informed', 'statements', 'paper', 'electronic', 'reflect', 'closed', 'status', 'clearly', 'indicate', 'available', 'credit', 'account', 'closed', 'credit', 'available', 'statement', 'list', '000', 'available', 'credit', 'would', 'like', 'cfpb', 'either', 'force', 'bofa', 'issue', 'accurate', 'statements', 'reinstate', 'card', 'status', 'matches', 'statement'), 1), (('hello', 'opened', 'new', 'citi', 'bank', 'account', 'account', 'promotional', 'offer', 'attached', 'believe', 'satisfied', 'terms', 'promotional', 'offer', 'citi', 'wish', 'honor', 'promotional', 'offer', 'direct', 'correspondence', 'citi', 'xxxx2016', 'citi', 'says', 'terms', 'conditions', 'promotion', 'follows', '1', 'open', 'new', 'regular', 'checking', 'account', 'citigold', 'citibank', 'account', 'package', 'xxxx2016', '2', 'within', '30', 'days', 'account', 'opening', 'make', 'minimum', 'deposit', '1500000', 'new', 'checking', 'new', 'existing', 'savings', 'plus', 'account', '3', 'minimum', 'balance', '1500000', 'required', 'maintained', 'checking', 'account', 'existing', 'citibank', 'savings', 'plus', 'account', '30', 'days', 'date', 'deposit', 'made', 'satisfied', 'terms', 'conditions', 'citi', 'honor', 'promotional', 'offer', 'claim', 'current', 'signatory', 'joint', 'citi', 'banking', 'account', 'wife', 'negates', 'eligibility', 'promotional', 'offer', 'believe', 'citi', 'mislead', 'correspondence', 'citi', 'xxxx2016', 'citi', 'says', 'state', 'clearly', 'terms', 'conditions', 'approved', 'offer', 'meet', 'terms', 'shall', 'attach', 'correspondence', 'citi', 'complaint', 'thank'), 1), (('purchased', 'items', 'two', 'retail', 'stores', 'one', 'online', 'xxxx19', 'one', 'store', 'xxxx19', 'used', 'citibank', 'debit', 'card', 'purchases', 'later', 'needed', 'return', 'part', 'purchase', 'order', 'value', '12000', 'item', 'value', '4900', 'went', 'store', 'return', 'item', 'xxxx19', 'mailed', 'items', 'back', 'await', 'refund', 'xxxx19', 'needed', 'close', 'citibank', 'account', 'following', 'day', 'xxxx19', 'told', 'citibank', 'pending', 'transactions', 'account', 'safe', 'close', 'informed', 'refund', 'would', 'process', 'closed', 'account', 'would', 'instead', 'bounce', 'back', 'point', 'would', 'able', 'request', 'send', 'money', 'different', 'account', 'gave', 'similar', 'information', 'refund', 'bounce', 'back', 'could', 'process', 'refund', 'different', 'account', 'waiting', 'requested', 'amount', 'time', 'retailers', '10', 'business', 'days', 'contacted', 'retailers', 'asked', 'money', 'bounced', 'back', 'however', 'money', 'accepted', 'citibank', 'sent', 'proofbank', 'response', 'codes', 'attached', 'called', 'citibank', 'locate', 'missing', 'refunds', 'however', 'informed', 'possibility', 'money', 'deposited', 'closed', 'account', 'receive', 'funds', 'since', 'ive', 'visited', 'several', 'branches', 'spoken', 'several', 'representatives', 'citibank', 'citibank', 'could', 'locate', 'funds', 'therefore', 'funds', 'still', 'retailers', 'bankers', 'ev ...
# Identity Theft or Fraud
# [(('disputing', 'fraudulant', 'charges', 'made', 'macy', 'acct', 'used', 'contacted', 'macys', 'numerous', 'times', 'report', 'filled', 'required', 'fraud', 'information', 'finally', 'sent', 'received', 'letter', 'week', 'later', 'stating', 'investigated', 'claim', 'confirmed', 'acct', 'belongs', 'questions', 'contact', 'called', 'transferred', '3', 'times', 'connected', 'collection', 'agency', 'also', 'provided', 'number', 'transferred', 'person', 'answered', 'phone', 'home', 'number', 'advised', 'keeps', 'getting', 'calls', 'people', 'home', 'number', 'went', 'number', 'provided', 'gentlemen', 'confirmed', 'indeed', 'home', 'number', '16', 'years', 'getting', 'run', 'around', 'macy', 'acct', 'collection', 'made', 'purchase', 'back', '2014', 'noticed', 'credit', 'reports', 'immediately', 'attempted', 'contact', 'keep', 'pushing', 'around', 'affecting', 'credit', 'furious', 'macy', 'point', 'next', 'going', 'obtain', 'legal', 'advise', 'issue', 'resolved', 'time', 'put', 'ridicilous', 'giving', 'someone', 'home', 'number', 'saying', 'number', 'collection', 'agency', 'ridicilous'), 1), (('would', 'like', 'remove', 'fraud', 'alerts'), 1), (('macy', 'contacted', '2016', 'stated', 'believed', 'fraudulent', 'activity', 'macy', 'credit', 'card', 'felt', 'charges', 'fraudulent', 'merchandise', 'shipped', 'home', 'address', 'confirmed', 'definitely', 'made', 'fraudulent', 'purchases', 'macy', 'assured', 'fraudulent', 'charges', 'would', 'fully', 'investigated', 'would', 'removed', 'charge', 'account', 'stated', 'since', 'charges', 'would', 'removed', 'nothing', 'none', 'purchases', 'card', 'time', 'fraudulent', 'activity', 'used', 'since', 'incident', 'charges', 'remain', 'account', 'placing', 'late', 'charges', 'account', 'non', 'payment'), 1), (('bought', 'item', 'paypal', 'transaction', 'looked', 'shady', 'notified', 'paypal', 'could', 'nothing', 'closed', 'dispute', 'leaving', '9900', 'item', 'never', 'delivered', 'sent', 'unknown', 'address', 'ny', 'reached', 'tell', 'item', 'never', 'received', 'sent', 'unknown', 'address', 'still', 'received', 'help', 'want', 'money', 'back', 'youll', 'see', 'paypal', 'card', 'statement', '9900', 'shipped', 'ny', 'united', 'states', 'received', 'order', 'xxxx2022', 'sent', 'status', 'shipped', 'transaction', 'id', 'contact', 'info', 'note', 'thank', 'completing', 'order', 'online', 'service', 'store', 'please', 'check', 'complete', 'payment', 'confirm', 'payment', 'shall', 'notify', 'soon', 'questions', 'please', 'contact', 'us', 'looking', 'forward', 'feedback', 'details', 'sent', '9900', 'total', '9900'), 1), (('submitting', 'complaint', 'target', 'cause', 'continue', 'report', 'fraudulent', 'account', 'authorize', 'opened', 'name', 'sold', 'account', 'xxxxxxxx', 'able', 'resolve', 'issue', 'get', 'fraudulent', 'account', 'removed', 'file', 'xxxxxxxx', 'put', 'complaint', 'target', 'refused', 'remove', 'account', 'even', 'though', 'provided', 'supporting', 'documents', 'claim', 'proceeded', 'report', 'charge', 'xxxxxxxx', 'put', 'worst', 'predicament', 'requesting', 'fraudulent', 'account', 'removed', 'file', 'sent', 'police', 'report', 'letter', 'going', 'attach', 'complaint', 'well'), 1), (('received', 'text', 'message', 'bank', 'america', 'text', 'line', 'asking', 'authorized', 'transaction', 'afternoon', 'sent', 'back', 'text', 'saying', 'called', 'bank', 'america', 'representative', 'alerted', 'text', 'message', 'person', 'verified', 'last', 'four', 'bank', 'number', 'account', 'number', 'amount', 'checking', 'savings', 'account', 'person', 'told', 'send', 'series', 'transactions', 'via', 'phone', 'number', 'sent', 'three', 'transactions', '150000', '20000', '20000', 'person', 'explained', 'amount', 'would', 'credited', 'back', 'account', 'funds', 'withdrawn', 'account', 'alarmed', 'person', 'hung', 'phone', 'called', 'number', 'back', 'avail', 'called', 'general', 'bank', 'america', 'line', 'representative', 'filed', 'three', 'separate', 'fraud', 'claims', 'transaction', 'received', 'em ...
# Debit Card Help
# [(('charge', 'charged', 'card', 'authorization', 'stayed', 'hotel', 'told', 'would', 'drop', 'decided', 'pay', 'increments', 'hotel', 'stay', '33000', '16000', '89000', 'nt', 'know', 'long', 'would', 'staying', 'whole', 'reservation', 'home', 'nt', 'ready', 'move', 'changed', 'reservation', 'checking', 'noticed', 'credit', 'card', 'charge', 'full', 'amount', '130000', 'authorization', 'never', 'dropped', 'happened', 'contacted', 'bank', 'america', 'dispute', 'filed', 'claim', 'duplicate', 'charges', 'charges', 'credit', 'back', 'permanent', 'credit', '33000', '16000', 'still', 'credited', 'back', 'going', 'back', 'forth', 'bank', 'trying', 'get', 'resolved', 'bank', 'made', 'errors', 'resubmitting', 'caused', 'delays', 'issues', 'claim', 'error', 'received', 'claim', 'response', 'merchant', 'allowed', 'submit', 'rebuttal', 'claim', 'faxed', 'back', 'bank', 'amounts', 'process', 'correctly', 'part', 'amount', 'stated', 'past', 'time', 'frame', 'clearly', 'responded', 'immediately', 'requested', 'along', 'others', 'gave', 'credit', 'back', 'past', 'time', 'frame', 'called', 'back', 'resubmit', '89000', 'time', 'even', 'specified', 'statement', 'file', 'showing', 'charge', 'made', 'another', 'card', 'never', 'refunded', 'never', 'received', 'notiice', 'result', 'claim', 'response', 'since', 'however', 'receive', 'response', '16000', 'amount', 'stated', 'permanent', 'credit', 'called', 'bank', 'check', 'status', 'submitted', 'claim', 'incorrectly', 'nt', 'notify', 'whatsoever', 'result', 'update', 'phone', 'call', 'matter', 'account', 'got', 'closed', '50000', 'amount', 'resulted', 'charge', 'reversed', 'temp', 'credit', 'prior', 'getting', 'rebuttal', 'proof', 'duplicate', 'charge', 'notified', 'provided', 'every', 'document', 'makes', 'sense', 'transactions', 'thing', 'stay', 'hotel', 'charge', 'refunded', 'issue'), 1), (('robbed', 'atm', 'seen', 'camera', 'footage', 'requested', 'bank', 'review', 'information', 'help', 'recover', 'costs', 'proceed', 'police', 'complains', 'show', 'proof', 'attempted', 'resolve', 'issue', 'meaningful', 'way'), 1), (('problem', 'bank', 'account', 'lost', 'debit', 'card', 'transaction', 'made', 'account', 'authorize', 'please', 'help', 'resolved', 'issue', 'made', 'claim', 'td', 'bank', '4100', 'fee', '17000', 'made', 'transaction', 'bank', 'according', 'bank', 'investigation', 'saying', 'charges', 'valid', 'transaction', 'valid', 'bank', 'denied', 'credit', 'transaction', 'please', 'help', 'resolved', 'issue', 'use', 'account', 'ssi', 'social', 'security', 'direct', 'deposit', 'account', 'right', 'negative', '19000', 'made', 'transaction', 'also', 'made', 'police', 'report', 'problem'), 1), (('used', 'account', 'years', 'closed', 'account', 'cut', 'bank', 'card', 'xxxxxxxx', 'xxxxxxxx', 'cleared', 'debt', 'also', 'verified', 'open', 'accounts', 'outstanding', 'balance', 'today', 'received', 'call', 'stating', 'bank', 'card', 'used', 'wanted', 'verify', 'one', 'used', 'means', 'bank', 'reopened', 'account', 'issued', 'new', 'card', 'name', 'without', 'consent'), 1), (('attempted', 'purchase', 'gas', 'wed', 'evening', 'gas', 'station', 'always', 'purchase', 'gas', 'gas', 'station', 'route', 'ny', 'use', 'speedpass', 'linked', 'debit', 'card', 'citibank', 'checking', 'account', 'done', 'many', 'many', 'years', 'purchase', 'declined', 'several', 'times', 'knew', 'citibank', 'sent', 'new', 'debit', 'card', 'went', 'home', 'activated', 'new', 'credit', 'card', 'attempted', 'purchase', 'gas', 'thurs', 'morning', 'twice', 'tried', 'speedpass', 'declined', 'tried', 'debit', 'card', 'pump', 'declined', 'went', 'store', 'swiped', 'debit', 'card', 'declined', 'borrowed', 'cash', 'able', 'put', 'enough', 'gas', 'car', 'order', 'go', 'work', 'thursday', 'friday', 'morning', 'went', 'citibank', 'online', 'account', 'able', 'get', 'online', 'accounts', 'showed', 'credit', 'card', 'cd', 'checking', 'account', 'savings', 'account', 'display', 'tried', 'hours', 'later', 'thing', 'called', 'customer', 'service', 'sa ...
# Billing or Debt Disputes
# [(('macy', 'sent', 'us', 'overdue', 'bill', 'bill', 'already', 'paid', 'new', 'bill', '2500', 'late', 'fee', '200', 'interest', 'charge', 'neveraccure', 'interest', 'called', 'paid', 'new', 'bill', 'minus', 'late', 'feeover', 'phone', 'would', 'remove', 'interest', 'charge', 'got', 'proof', 'payment', 'bank', 'original', 'charge', 'faxed', 'macy', 'payment', 'research', 'heard', 'called', 'today', 'upset', 'hold', 'timexxxx', 'toldthem', 'hung'), 1), (('american', 'express', 'charged', '300', 'processing', 'fee', 'item', 'purchased', 'company', 'never', 'informed', 'advance', 'would', 'charged', 'fee', 'nt', 'authorize', 'american', 'express', 'refuses', 'credit', 'fee', 'insisting', 'charge', 'valid'), 1), (('bank', 'america', 'new', 'york', 'refusing', 'help', 'customer', 'made', 'fun', 'outfit', 'demand', 'response', 'wish', 'prosecute', 'person', 'public', 'intimidation', 'humiliation', 'event'), 1), (('fraudulent', 'account', 'credit', 'report', 'become', 'egregious', 'mine', 'know', 'used', 'name', 'came', 'debit', 'mine', 'auto', 'lease', 'debt', 'cant', 'say', 'emphatically', 'never', 'account', 'life', 'could', 'please', 'remove', 'immediately', 'also', 'exercising', 'right', 'fair', 'credit', 'reporting', 'act', 'section', '609', 'request', 'information', 'regarding', 'item', 'listed', 'consumer', 'credit', 'report', 'per', 'section', '609', 'entitled', 'see', 'source', 'information', 'original', 'contract', 'contains', 'signature', 'document', 'isnt', 'debt', 'please', 'remove', 'asap'), 1), (('caine', 'weiner', 'compa', 'original', 'creditor', 'failed', 'send', 'response', 'requested', 'information', 'alleged', 'collection', 'account', 'within', 'first', 'five', 'initial', 'days', 'receiving', 'dispute', 'already', 'suffering', 'enough', 'inaccurate', 'data', 'credit', 'report', 'prepare', 'ways', 'circumvent', 'talking', 'financial', 'status', 'shortcomings', 'everyone', 'family', 'members', 'coworkers', 'causing', 'changes', 'relationships', 'shaped', 'life', 'day', 'stress', 'comes', 'alleged', 'debt', 'ruining', 'creditworthiness', 'managed', 'single', 'mother', 'financial', 'expectations', 'required', 'meet', 'unimaginable', 'nobrainer', 'financial', 'boost', 'good', 'credit', 'offers', 'would', 'better', 'shape', 'face', 'daily', 'challenges', 'come', 'current', 'predicament', 'due', 'lenders', 'turning', 'applications', 'forced', 'move', 'original', 'state', 'ended', 'current', 'address', 'family', 'close', 'friends', 'vent', 'leaving', 'visiting', 'social', 'programs', 'help', 'deal', 'stress', 'contact', 'company', 'alleged', 'debt', 'response', 'furthermore', 'caine', 'weiner', 'compa', 'original', 'creditor', 'also', 'reporting', 'alleged', 'debt', 'account', 'inaccurate', 'according', 'usc', 'title', '15', '1693a2', 'therefore', 'point', 'collection', 'agency', 'knowingly', 'furnishing', 'false', 'data', 'credit', 'report', 'violation', 'of15', 'us', 'code', '1692e', 'false', 'misleading', 'representations', 'demand', 'cease', 'desistfurnishing', 'alleged', 'debt', 'notify', 'credit', 'reporting', 'agencies', 'delete', 'immediately'), 1), (('contacted', 'diversified', 'consultants', 'past', 'bill', 'belong', 'previously', 'removed', 'fraudulent', 'account', 'credit', 'report', 'put', 'back', 'previously', 'notified', 'collection', 'agency', 'owe', 'debt', 'yet', 'without', 'contacting', 'whatsoever', 'put', 'debt', 'credit', 'report', 'debt', 'belong', 'collection', 'agency', 'using', 'fraudulent', 'information', 'ruin', 'credit', 'report', 'done'), 1), (('company', 'allied', 'recovery', 'solutions', 'contacted', 'mail', 'several', 'time', 'throughout', 'two', 'years', 'time', 'demanding', 'pay', '17000000', 'claim', 'accident', 'occurred', 'two', 'years', 'ago', 'claim', 'closed', 'wont', 'stop', 'sending', 'harassing', 'letters', 'threatening', 'action', 'dont', 'pay'), 1), (('eos', 'cca', 'original', 'creditor', 'failed', 'send', 'response', 'requested', 'information', 'alleged', 'collection', 'accou ...
# Service Disputes
# [(('discover', 'financial', 'services', 'reported', 'negative', 'marks', 'credit', 'report', 'presenting', 'option', 'resolve', 'problem'), 1), (('repaying', 'federal', 'student', 'loans', 'since', 'xxxx12', 'switched', 'fed', 'loans', 'always', 'enrolled', 'income', 'based', 'repayment', 'plan', 'worked', 'nonprofit', 'still', 'waiting', 'updated', 'loan', 'count', 'requested', 'loans', 'counted', 'months', 'paid', 'fed', 'loans', 'called', 'fed', 'loans', 'multiple', 'times', 'update', 'told', 'way', 'tell', 'delay'), 1), (('collection', 'agency', 'making', 'harassing', 'phone', 'calls', 'fathers', 'home', 'debt', 'owed', 'dont', 'live', 'house', 'lived', '12', 'years', 'sent', 'letter', 'stating', 'sending', 'letters', 'name', 'saying', 'owe', 'money'), 1), (('loan', 'managed', 'aes', 'original', 'balance', '12', 'years', 'paid', 'principal', 'paid', '6600000', 'interest', 'paid', '3400000', 'may', 'paid', 'couple', 'days', 'late', 'one', 'twice', 'deferred', 'one', 'month', 'twice', 'nothing', 'account', 'seems', 'applied', 'nothing', 'ive', 'always', 'paid', 'time', 'balance', 'gone', '12', 'years', 'paid', 'towards', 'balance', 'gone', 'downxxxx', 'call', 'ask', 'possible', 'one', 'investigate', 'help', 'figure', 'dont', 'know', 'else', 'turn', 'accountants', 'always', 'tell', 'dont', 'specialize', 'student', 'loans', 'considering', 'much', 'recent', 'scrutiny', 'aes', 'pheaa', 'concerned', 'account', 'isnt', 'handled', 'properly', 'help', 'greatly', 'appreciated', 'thank'), 1), (('entered', 'branch', 'bank', 'america', 'xxxxxxxx', 'ny', '2015', 'cash', 'denominated', 'check', 'bank', 'america', 'checking', 'account', 'filled', 'forms', 'told', 'would', 'take', 'weeks', 'almost', 'months', 'tried', 'inquire', 'twice', 'customer', 'service', 'one', 'even', 'understands', 'talking', 'one', 'bank', 'america', 'followed', 'issue'), 1), (('responded', 'email', 'offer', 'american', 'express', 'offering', 'membership', 'rewards', 'person', 'added', 'account', 'spend', '25000', 'first', '3', 'months', 'added', 'son', 'daughter', 'spent', 'excess', '25000', 'within', 'first', '3', 'months', 'added', 'account', 'contacted', 'amex', 'claim', 'link', 'accessed', 'time', 'added', 'dispute', 'terms', 'met', 'find', 'deceptive', 'practice', 'contacted', 'amex', 'failed', 'resolve', 'issue', 'communicated', 'representative', 'one', 'hour', 'hrs', 'thru', 'hrs', 'stated', 'would', 'open', 'investigation', 'take', '68', 'weeks', 'complete', 'email', 'offer', 'received', 'xxxxxxxx', 'add', 'significant', 'employee', 'child', '13', 'account', 'give', 'access', 'little', 'pleasures', 'unforgettable', 'experiences', 'come', 'carrying', 'american', 'express', 'card', 'whenever', 'make', 'eligible', 'purchase', 'trip', 'favorite', 'taco', 'truck', 'new', 'set', 'trainers', 'youll', 'earn', 'rewards', 'earn', 'membership', 'rewards', 'points', 'add', 'new', 'additional', 'card', 'members', 'account', 'email', 'earn', 'membership', 'rewards', 'points', 'spend', '25000', 'eligible', 'purchases', 'card', 'first', '3', 'months', 'card', 'membership', 'limit', 'membership', 'rewards', 'points', 'offer', 'ends', 'xxxxxxxx', 'son', 'spent', '36000', 'daughter', '25000', 'date'), 1), (('logged', 'american', 'express', 'account', 'saw', 'targeted', 'offer', 'offer', 'apply', 'upgrade', 'card', 'american', 'express', 'terms', 'offer', 'stated', 'approved', 'would', 'earn', 'points', 'spending', '300000', '3', 'months', 'met', 'terms', 'offer', 'within', 'time', 'period', 'points', 'credited', 'account', 'contacted', 'american', 'express', 'several', 'times', 'time', 'eligible', 'offer', 'think', 'bait', 'switch', 'move', 'eligible', 'offer', 'american', 'express', 'target', 'account', 'website', 'screen', 'shot', 'offer', 'logged', 'american', 'express', 'account'), 1), (('never', 'gave', 'permission', 'organization', 'information', 'sent', 'attached', 'mailing', 'constitutes', 'several', 'federal', 'violations', 'pursuant', '18', 'usc', '241', 'organizat ...
